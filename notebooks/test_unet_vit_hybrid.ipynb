# %%
import torch
import torch.nn.functional as F
import sys
import os
sys.path.append("../")       # one folder up
sys.path.append("../models")

from models.baseline_Unet_ViT import (
    Convblock,
    EncodeBlock,
    DecodeBlock,
    ViTBottleneck,
    BottleneckViT,
    U_net_ViT,
)


def print_header(msg):
    print("\n" + "=" * 80)
    print(msg)
    print("=" * 80)

# %%
#test convblock
def test_convblock():
    print_header("TEST 1: Convblock")

    x = torch.randn(1, 3, 64, 64)
    block = Convblock(3, 16, filter_size=3, padding=1, normalize=True)

    out = block(x)
    print("Convblock output shape:", out.shape)

#test encode block
def test_encodeblock():
    print_header("TEST 2: EncodeBlock")

    x = torch.randn(1, 3, 128, 128)
    block = EncodeBlock(3, 16, residual_channels=16, padding=1, normalize=True)

    pooled, residual = block(x)
    print("EncodeBlock pooled shape:  ", pooled.shape)
    print("EncodeBlock residual shape:", residual.shape)

#test decode block
def test_decodeblock():
    print_header("TEST 3: DecodeBlock")

    # Simulate decoder stage input
    x = torch.randn(1, 128, 32, 32)

    residual = torch.randn(1, 64, 64, 64)


    block = DecodeBlock(128, 64, up_size=2, padding=1, residual="interpolate")

    out = block(x, residual)
    print("DecodeBlock output shape:", out.shape)

#test ViT bottleneck only
def test_vitbottleneck():
    print_header("TEST 4: ViTBottleneck (standalone)")

    x = torch.randn(1, 128, 16, 16)  # b, c, h, w (typical bottleneck)
    vit = ViTBottleneck(128, num_layers=2, num_heads=4)

    out = vit(x)
    print("ViTBottleneck output shape:", out.shape)

#test BottleneckViT (conv + transformer)
def test_bottleneck_vit():
    print_header("TEST 5: BottleneckViT (conv + transformer)")

    x = torch.randn(1, 64, 32, 32)
    bn = BottleneckViT(
        in_channels=64,
        bottleneck_channels=128,
        normalize=True,
        vit_num_layers=2,
        vit_num_heads=4,
        filter_size=3,
    )

    out = bn(x)
    print("BottleneckViT output shape:", out.shape)

#test full U-Net ViT on single size
def test_full_model_single():
    print_header("TEST 6: Full U_net_ViT model (single pass)")

    x = torch.randn(1, 1, 572, 572)

    model = U_net_ViT(
        encode_in=(1, 64, 128, 256),
        encode_out=(64, 128, 256, 512),
        decode_in=(1024, 512, 256, 128),
        decode_out=(512, 256, 128, 64),
        normalize=True,
        upsampling="bilinear",
        residual="interpolate",
        vit_num_layers=2,
        vit_num_heads=4,
    )

    out = model(x)
    print("Model output shape:", out.shape)

#test full U-Net ViT on multiple input sizes
def test_multi_input_sizes():
    print_header("TEST 7: Full model with multiple input sizes")

    sizes = [
        (128, 128),
        (256, 256),
        (320, 320),
        (572, 572),
    ]

    model = U_net_ViT()

    for h, w in sizes:
        x = torch.randn(1, 1, h, w)
        y = model(x)
        print(f"Input {h}x{w} → Output:", y.shape)

#test different transformer variants in bottleneck (multi layesrs/heads)
def test_transformer_variants():
    print_header("TEST 8: Transformer bottleneck variants")

    configs = [
        {"layers": 1, "heads": 2},
        {"layers": 2, "heads": 4},
        {"layers": 4, "heads": 8},
    ]

    x = torch.randn(1, 1, 256, 256)

    for cfg in configs:
        print(f"\nTesting ViT config: {cfg}")
        model = U_net_ViT(
            vit_num_layers=cfg["layers"],
            vit_num_heads=cfg["heads"],
        )
        out = model(x)
        print("Output:", out.shape)

#stress test with very small bottleneck
def test_small_bottleneck():
    print_header("TEST 9: Very small bottleneck (8x8) stress test")

    # Forcing small sizes to ensure flatten <-> spatial reshape is correct
    x = torch.randn(1, 1, 64, 64)

    model = U_net_ViT(
        encode_in=(1, 32),
        encode_out=(32, 64),
        decode_in=(128, 64),
        decode_out=(64, 32),
        vit_num_layers=3,
        vit_num_heads=4,
    )

    out = model(x)
    print("Output shape:", out.shape)

#patch sequence and size validation (token correctness test)
def test_token_shape_correctness():
    print_header("TEST 10: Token shape correctness in ViTBottleneck")

    b, c, h, w = 2, 64, 20, 20
    x = torch.randn(b, c, h, w)
    vit = ViTBottleneck(c)

    out = vit(x)
    print("Token test output:", out.shape)
    assert out.shape == (b, c, h, w), "Token reshape error!"

# %%
if __name__ == "__main__":
    test_convblock()
    test_encodeblock()
    test_decodeblock()
    test_vitbottleneck()
    test_bottleneck_vit()
    test_full_model_single()
    test_multi_input_sizes()
    test_transformer_variants()
    test_small_bottleneck()
    test_token_shape_correctness()

    print("\nAll tests completed successfully.")
# Out:
# ================================================================================
# TEST 1: Convblock
# ================================================================================
# Size: torch.Size([1, 3, 64, 64])
# Size: torch.Size([1, 16, 64, 64])
# Size: torch.Size([1, 16, 64, 64])
# Convblock output shape: torch.Size([1, 16, 64, 64])
#
# ================================================================================
# TEST 2: EncodeBlock
# ================================================================================
# Size: torch.Size([1, 3, 128, 128])
# Size: torch.Size([1, 16, 128, 128])
# Size: torch.Size([1, 16, 128, 128])
# EncodeBlock pooled shape:   torch.Size([1, 16, 64, 64])
# EncodeBlock residual shape: torch.Size([1, 16, 128, 128])
#
# ================================================================================
# TEST 3: DecodeBlock
# ================================================================================
# Size: torch.Size([1, 128, 64, 64])
# Size: torch.Size([1, 64, 64, 64])
# Size: torch.Size([1, 128, 64, 64])
# Size: torch.Size([1, 128, 64, 64])
# Size: torch.Size([1, 64, 64, 64])
# Size: torch.Size([1, 64, 64, 64])
# DecodeBlock output shape: torch.Size([1, 64, 64, 64])
#
# ================================================================================
# TEST 4: ViTBottleneck (standalone)
# ================================================================================
# ViTBottleneck output shape: torch.Size([1, 128, 16, 16])
#
# ================================================================================
# TEST 5: BottleneckViT (conv + transformer)
# ================================================================================
# BottleneckViT output shape: torch.Size([1, 128, 28, 28])
#
# ================================================================================
# TEST 6: Full U_net_ViT model (single pass)
# ================================================================================
# Size: torch.Size([1, 1, 572, 572])
# Size: torch.Size([1, 64, 570, 570])
# Size: torch.Size([1, 64, 568, 568])
# Size: torch.Size([1, 64, 284, 284])
# Size: torch.Size([1, 128, 282, 282])
# Size: torch.Size([1, 128, 280, 280])
# Size: torch.Size([1, 128, 140, 140])
# Size: torch.Size([1, 256, 138, 138])
# Size: torch.Size([1, 256, 136, 136])
# Size: torch.Size([1, 256, 68, 68])
# Size: torch.Size([1, 512, 66, 66])
# Size: torch.Size([1, 512, 64, 64])
# Size: torch.Size([1, 1024, 56, 56])
# Size: torch.Size([1, 512, 56, 56])
# Size: torch.Size([1, 1024, 56, 56])
# Size: torch.Size([1, 1024, 56, 56])
# Size: torch.Size([1, 512, 54, 54])
# Size: torch.Size([1, 512, 52, 52])
# Size: torch.Size([1, 512, 104, 104])
# Size: torch.Size([1, 256, 104, 104])
# Size: torch.Size([1, 512, 104, 104])
# Size: torch.Size([1, 512, 104, 104])
# Size: torch.Size([1, 256, 102, 102])
# Size: torch.Size([1, 256, 100, 100])
# Size: torch.Size([1, 256, 200, 200])
# Size: torch.Size([1, 128, 200, 200])
# Size: torch.Size([1, 256, 200, 200])
# Size: torch.Size([1, 256, 200, 200])
# Size: torch.Size([1, 128, 198, 198])
# Size: torch.Size([1, 128, 196, 196])
# Size: torch.Size([1, 128, 392, 392])
# Size: torch.Size([1, 64, 392, 392])
# Size: torch.Size([1, 128, 392, 392])
# Size: torch.Size([1, 128, 392, 392])
# Size: torch.Size([1, 64, 390, 390])
# Size: torch.Size([1, 64, 388, 388])
# Model output shape: torch.Size([1, 2, 388, 388])
#
# ================================================================================
# TEST 7: Full model with multiple input sizes
# ================================================================================
# Size: torch.Size([1, 1, 128, 128])
# Size: torch.Size([1, 64, 126, 126])
# Size: torch.Size([1, 64, 124, 124])
# Size: torch.Size([1, 128, 116, 116])
# Size: torch.Size([1, 64, 116, 116])
# Size: torch.Size([1, 128, 116, 116])
# Size: torch.Size([1, 128, 116, 116])
# Size: torch.Size([1, 64, 114, 114])
# Size: torch.Size([1, 64, 112, 112])
# Input 128x128 → Output: torch.Size([1, 2, 112, 112])
# Input 256x256 → Output: torch.Size([1, 2, 240, 240])
# Input 320x320 → Output: torch.Size([1, 2, 304, 304])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 8
#       6 test_bottleneck_vit()
#       7 test_full_model_single()
# ----> 8 test_multi_input_sizes()
#       9 test_transformer_variants()
#      10 test_small_bottleneck()
#
# Cell In[2], line 100, in test_multi_input_sizes()
#      98 for h, w in sizes:
#      99     x = torch.randn(1, 1, h, w)
# --> 100     y = model(x)
#     101     print(f"Input {h}x{w} → Output:", y.shape)
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File p:\DTU Fall 2025\Deep Learning\Project\Deep-learning-for-segmentation-of-micro-tomography-images\notebooks\..\models\baseline_Unet_ViT.py:366, in U_net_ViT.forward(self, x)
#     363     residuals.append(residual)
#     365 # Bottleneck (conv + Transformer)
# --> 366 x = self.bottleneck(x)
#     368 # Decode with concat
#     369 residuals = residuals[::-1]
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File p:\DTU Fall 2025\Deep Learning\Project\Deep-learning-for-segmentation-of-micro-tomography-images\notebooks\..\models\baseline_Unet_ViT.py:272, in BottleneckViT.forward(self, x)
#     270 x = self.bn2(x)
#     271 x = self.act(x)
# --> 272 x = self.vit(x)
#     273 return x
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File p:\DTU Fall 2025\Deep Learning\Project\Deep-learning-for-segmentation-of-micro-tomography-images\notebooks\..\models\baseline_Unet_ViT.py:224, in ViTBottleneck.forward(self, x)
#     221 tokens = x.view(b, c, h * w).permute(0, 2, 1)
#     223 # Apply Transformer encoder
# --> 224 tokens = self.encoder(tokens)
#     226 # Reshape back to (B, C, H, W)
#     227 x_out = tokens.permute(0, 2, 1).view(b, c, h, w)
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\transformer.py:524, in TransformerEncoder.forward(self, src, mask, src_key_padding_mask, is_causal)
#     521 is_causal = _detect_is_causal_mask(mask, is_causal, seq_len)
#     523 for mod in self.layers:
# --> 524     output = mod(
#     525         output,
#     526         src_mask=mask,
#     527         is_causal=is_causal,
#     528         src_key_padding_mask=src_key_padding_mask_for_layers,
#     529     )
#     531 if convert_to_nested:
#     532     output = output.to_padded_tensor(0.0, src.size())
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\transformer.py:935, in TransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask, is_causal)
#     931     x = x + self._ff_block(self.norm2(x))
#     932 else:
#     933     x = self.norm1(
#     934         x
# --> 935         + self._sa_block(x, src_mask, src_key_padding_mask, is_causal=is_causal)
#     936     )
#     937     x = self.norm2(x + self._ff_block(x))
#     939 return x
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\transformer.py:949, in TransformerEncoderLayer._sa_block(self, x, attn_mask, key_padding_mask, is_causal)
#     942 def _sa_block(
#     943     self,
#     944     x: Tensor,
#    (...)
#     947     is_causal: bool = False,
#     948 ) -> Tensor:
# --> 949     x = self.self_attn(
#     950         x,
#     951         x,
#     952         x,
#     953         attn_mask=attn_mask,
#     954         key_padding_mask=key_padding_mask,
#     955         need_weights=False,
#     956         is_causal=is_causal,
#     957     )[0]
#     958     return self.dropout1(x)
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\modules\activation.py:1380, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1354     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1355         query,
#    1356         key,
#    (...)
#    1377         is_causal=is_causal,
#    1378     )
#    1379 else:
# -> 1380     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1381         query,
#    1382         key,
#    1383         value,
#    1384         self.embed_dim,
#    1385         self.num_heads,
#    1386         self.in_proj_weight,
#    1387         self.in_proj_bias,
#    1388         self.bias_k,
#    1389         self.bias_v,
#    1390         self.add_zero_attn,
#    1391         self.dropout,
#    1392         self.out_proj.weight,
#    1393         self.out_proj.bias,
#    1394         training=self.training,
#    1395         key_padding_mask=key_padding_mask,
#    1396         need_weights=need_weights,
#    1397         attn_mask=attn_mask,
#    1398         average_attn_weights=average_attn_weights,
#    1399         is_causal=is_causal,
#    1400     )
#    1401 if self.batch_first and is_batched:
#    1402     return attn_output.transpose(1, 0), attn_output_weights
#
# File c:\Users\Zoubir\anaconda3\Lib\site-packages\torch\nn\functional.py:6484, in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v, average_attn_weights, is_causal)
#    6481 k = k.view(bsz, num_heads, src_len, head_dim)
#    6482 v = v.view(bsz, num_heads, src_len, head_dim)
# -> 6484 attn_output = scaled_dot_product_attention(
#    6485     q, k, v, attn_mask, dropout_p, is_causal
#    6486 )
#    6487 attn_output = (
#    6488     attn_output.permute(2, 0, 1, 3).contiguous().view(bsz * tgt_len, embed_dim)
#    6489 )
#    6491 attn_output = linear(attn_output, out_proj_weight, out_proj_bias)
#
# RuntimeError: [enforce fail at alloc_cpu.cpp:121] data. DefaultCPUAllocator: not enough memory: you tried to allocate 98344960000 bytes.
