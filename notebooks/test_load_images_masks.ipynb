# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tifffile as tiff
from pathlib import Path

# %%
# Project root
project_root = Path.cwd().parents[0]

images_dir = project_root / "datas" / "Original Images"
masks_dir  = project_root / "datas" / "Original Masks"
nb_images = 22  # 00 to 21

def load_tiff_image(path):
    img = tiff.imread(path)
    if img.ndim == 3:   # takes middle slicee in case of 3D.
        img = img[img.shape[0] // 2]
    return img

# %%
images = []
masks = []

for i in range(nb_images):
    img_path = os.path.join(images_dir, f"image_v2_{i:02d}.tif")
    mask_path = os.path.join(masks_dir,  f"image_v2_mask_{i:02d}.tif")

    img = load_tiff_image(img_path)
    mask = load_tiff_image(mask_path)

    images.append(img)
    masks.append(mask)

    print(f"\n Img/mask Pair {i:02d}:")
    print(f"Image shape: {img.shape}, dtype: {img.dtype}")
    print(f"Image intensity stats:") #not sure if intensity is the right word
    print(f"    Min: {np.min(img):}, Max: {np.max(img):}, Mean: {np.mean(img):}")
    print(f"Mask shape: {mask.shape}, dtype: {mask.dtype}")
    print(f"Mask intensity stats:")  # //
    print(f"    Min: {np.min(mask):}, Max: {np.max(mask):}, Mean: {np.mean(mask):}")
# Out:
#  Img/mask Pair 00:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: -3.5173934520571493e-06, Max: 0.00043277101940475404, Mean: 0.00015297200297936797
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -0.0006558112800121307, Max: 0.00043277101940475404, Mean: 0.00011117623216705397
#
#  Img/mask Pair 01:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: -3.0874754884280264e-05, Max: 0.0004225051961839199, Mean: 0.00015832211647648364
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -0.00015204670489765704, Max: 0.00039509974885731936, Mean: 0.00012300899834372103
#
#  Img/mask Pair 02:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: -1.3774572835245635e-05, Max: 0.0003831683425232768, Mean: 0.0001647619646973908
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -0.00015204670489765704, Max: 0.0003527674125507474, Mean: 0.00012439630518201739
#
#  Img/mask Pair 03:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: -1.5860185158089735e-05, Max: 0.0003905215417034924, Mean: 0.00016922171926125884
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -0.00015204670489765704, Max: 0.0003905215417034924, Mean: 0.00013218200183473527
#
#  Img/mask Pair 04:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: -1.8085596821038052e-05, Max: 0.0003387765900697559, Mean: 0.00017379233031533659
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -0.00015204670489765704, Max: 0.0003527674125507474, Mean: 0.000135320849949494
#
#  Img/mask Pair 05:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 3.73526600014884e-05, Max: 0.00038508547004312277, Mean: 0.0001797803124645725
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -6.35334727121517e-05, Max: 0.0003527674125507474, Mean: 0.00015353398339357227
#
#  Img/mask Pair 06:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 2.913571552198846e-05, Max: 0.0004049724666401744, Mean: 0.0001842853962443769
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -7.016774907242507e-05, Max: 0.0003527674125507474, Mean: 0.00015785750292707235
#
#  Img/mask Pair 07:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 1.957650965778157e-05, Max: 0.00041681621223688126, Mean: 0.00018768591689877212
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -6.35334727121517e-05, Max: 0.0003527674125507474, Mean: 0.00016165856504812837
#
#  Img/mask Pair 08:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 3.2201583962887526e-05, Max: 0.0004425937950145453, Mean: 0.0001924290700117126
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -6.35334727121517e-05, Max: 0.0003528232919052243, Mean: 0.00016407242219429463
#
#  Img/mask Pair 09:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 2.8440636015147902e-05, Max: 0.00044410102418623865, Mean: 0.0001932522573042661
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -7.016774907242507e-05, Max: 0.0003527674125507474, Mean: 0.00016614906780887395
#
#  Img/mask Pair 10:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 4.421976700541563e-05, Max: 0.00041311277891509235, Mean: 0.00019485097436700016
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -7.016774907242507e-05, Max: 0.0003527674125507474, Mean: 0.00016054812294896692
#
#  Img/mask Pair 11:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 5.263110506348312e-05, Max: 0.00037558574695140123, Mean: 0.00019521935610100627
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -7.016774907242507e-05, Max: 0.0003592459252104163, Mean: 0.00015790187171660364
#
#  Img/mask Pair 12:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 4.448243635124527e-05, Max: 0.0003765850269701332, Mean: 0.0001973178586922586
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -7.016774907242507e-05, Max: 0.0003765850269701332, Mean: 0.00016192227485589683
#
#  Img/mask Pair 13:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 5.9340280131436884e-05, Max: 0.00037057744339108467, Mean: 0.00019684917060658336
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -6.35334727121517e-05, Max: 0.00037057744339108467, Mean: 0.00016454464639537036
#
#  Img/mask Pair 14:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 5.3252872021403164e-05, Max: 0.0004014137957710773, Mean: 0.00020067350124008954
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -7.016774907242507e-05, Max: 0.0004014137957710773, Mean: 0.00016362914175260812
#
#  Img/mask Pair 15:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 6.507224316010252e-05, Max: 0.00040632986929267645, Mean: 0.00020182476146146655
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -7.016774907242507e-05, Max: 0.00038043331005610526, Mean: 0.00016244906873907894
#
#  Img/mask Pair 16:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 5.9466343373060226e-05, Max: 0.00046860051224939525, Mean: 0.0001997456856770441
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -7.016774907242507e-05, Max: 0.00046860051224939525, Mean: 0.00016508794215042144
#
#  Img/mask Pair 17:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: -4.0724633436184376e-05, Max: 0.0005651357932947576, Mean: 0.0001996859791688621
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -6.35334727121517e-05, Max: 0.0005651357932947576, Mean: 0.0001676101383054629
#
#  Img/mask Pair 18:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 5.07555523654446e-05, Max: 0.0004916816833429039, Mean: 0.00019795744447037578
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -6.35334727121517e-05, Max: 0.00047725820331834257, Mean: 0.00016529909044038504
#
#  Img/mask Pair 19:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: -2.334021519345697e-05, Max: 0.00047160653048194945, Mean: 0.00019770528888329864
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -7.016774907242507e-05, Max: 0.00046846724580973387, Mean: 0.0001668487093411386
#
#  Img/mask Pair 20:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: -4.326110683905426e-06, Max: 0.0006820965209044516, Mean: 0.00019690299814101309
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -7.016774907242507e-05, Max: 0.0006820965209044516, Mean: 0.00016479990154039115
#
#  Img/mask Pair 21:
# Image shape: (768, 768), dtype: float32
# Image intensity stats:
#     Min: 3.6971709050703794e-05, Max: 0.00047601482947357, Mean: 0.00019672098278533667
# Mask shape: (768, 768), dtype: float32
# Mask intensity stats:
#     Min: -7.016774907242507e-05, Max: 0.00047601482947357, Mean: 0.00016411105752922595

# %%
num_to_show = nb_images 
plt.figure(figsize=(12, num_to_show * 4))
cmap = 'gray'

for i in range(num_to_show):
    img = images[i]
    mask = masks[i]

    plt.subplot(num_to_show, 2, 2 * i + 1)
    plt.imshow(img, cmap)
    plt.title(f"Image {i:02d}")
    plt.axis('off')

    plt.subplot(num_to_show, 2, 2 * i + 2)
    plt.imshow(mask, cmap)
    plt.title(f"Mask {i:02d}")
    plt.axis('off')

plt.tight_layout()
plt.show()
